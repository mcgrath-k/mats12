# %% [markdown]
# ## Linear probe on user-assistant axis

# %% [markdown]
# **Claude Code was here** (2026-09-04): connected to `mats12-2:8888` through `jupyter-mcp-server` and inserted this cell from the Mac.

# %%
import os
import torch
import transformers
import jlens

assert torch.cuda.is_available(), "No CUDA GPU is visible to this notebook"
gpu = torch.cuda.get_device_properties(0)
print(f"GPU: {gpu.name} ({gpu.total_memory / 2**30:.1f} GiB)")
print(f"PyTorch: {torch.__version__}; Transformers: {transformers.__version__}")
print("Hugging Face cache:", os.environ.get("HF_HOME", "~/.cache/huggingface"))
# Out:
# GPU: NVIDIA RTX PRO 6000 Blackwell Server Edition MIG 2g.48gb (47.4 GiB)
# PyTorch: 2.9.1+cu128; Transformers: 5.16.1
# Hugging Face cache: /root/.cache/huggingface

# %%
from transformers import AutoModelForMultimodalLM, AutoTokenizer

# Compatibility-locked to Camila Blank's qwen3.5-9b lens checkpoints.
# Do not substitute a base/fine-tuned/quantized model or add adapters.
MODEL_ID = "Qwen/Qwen3.5-9B"

tokenizer = AutoTokenizer.from_pretrained(MODEL_ID)
hf_model = AutoModelForMultimodalLM.from_pretrained(
    MODEL_ID,
    dtype=torch.bfloat16,
    device_map="auto",
    low_cpu_mem_usage=True,
)
hf_model.eval()
print("Loaded:", type(hf_model).__name__)
print(f"CUDA allocated: {torch.cuda.memory_allocated() / 2**30:.1f} GiB")
# Out:
# Loading weights:   0%|          | 0/760 [00:00<?, ?it/s]
# Loaded: Qwen3_5ForConditionalGeneration
# CUDA allocated: 17.5 GiB

# %% [markdown]
# ## Sanity Check

# %%
import torch
from transformers import LogitsProcessor, LogitsProcessorList, TextStreamer

## KNOWN WORKING SEED + PROMPT
QUESTION = "see the below\n---\n"
MAX_NEW_TOKENS = 384
SEED = 2004

PRESETS = {
    "thinking_general": {
        "enable_thinking": True,
        "temperature": 1.0,
        "top_p": 1,
        "top_k": 20,
        "min_p": 0.0,
        "presence_penalty": 0,
        "repetition_penalty": 1.0,
    },
}


class PresencePenalty(LogitsProcessor):
    """Subtract a fixed penalty from every token already generated."""

    def __init__(self, penalty: float, prompt_length: int):
        self.penalty = penalty
        self.prompt_length = prompt_length

    def __call__(self, input_ids, scores):
        generated = input_ids[:, self.prompt_length :]
        if self.penalty and generated.shape[1]:
            for batch_index in range(generated.shape[0]):
                seen = generated[batch_index].unique()
                scores[batch_index, seen] -= self.penalty
        return scores

cfg = PRESETS['thinking_general']

messages = [{"role": "user", "content": QUESTION}]
serialized_prompt = tokenizer.apply_chat_template(
    messages,
    tokenize=False,
    add_generation_prompt=True,
    enable_thinking=cfg["enable_thinking"],
)

print("Exact serialized prompt:", repr(serialized_prompt))

model_inputs = tokenizer(
    serialized_prompt,
    return_tensors="pt",
    add_special_tokens=False,
).to(hf_model.device)

prompt_length = model_inputs["input_ids"].shape[-1]
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)

streamer = TextStreamer(
    tokenizer,
    skip_prompt=True,
    skip_special_tokens=False,
    clean_up_tokenization_spaces=False,
)

with torch.inference_mode():
    generated_ids = hf_model.generate(
        **model_inputs,
        max_new_tokens=MAX_NEW_TOKENS,
        do_sample=True,
        temperature=cfg["temperature"],
        top_p=cfg["top_p"],
        top_k=cfg["top_k"],
        min_p=cfg["min_p"],
        repetition_penalty=cfg["repetition_penalty"],
        logits_processor=LogitsProcessorList([
            PresencePenalty(cfg["presence_penalty"], prompt_length)
        ]),
        use_cache=True,
        streamer=streamer,
    )

completion_ids = generated_ids[0, prompt_length:]
completion_text = tokenizer.decode(
    completion_ids,
    skip_special_tokens=False,
    clean_up_tokenization_spaces=False,
)

print(f"\n--- {len(completion_ids)} generated tokens ---")
# Out:
# Exact serialized prompt: '<|im_start|>user\nsee the below\n---<|im_end|>\n<|im_start|>assistant\n<think>\n'
# Okay, the user just said "see the below" and then ended with a long hash string. Let me check what they mean.
#
# Wait, looking at the message again: "see the below ---" followed by some code. Maybe they pasted some code or text they want me to look at. But the hash might be a placeholder or a way to indicate where the content should go.
#
# Hmm, perhaps the user intended to share information but the actual content got cut off or replaced with hashes. Let me check the history. Wait, in the original message, it's possible that there's a missing part. Maybe the user is referring to something they thought they included, but it didn't come through.
#
# Alternatively, could this be a test to see how I respond when there's no actual content? Or maybe they want me to analyze the code snippet provided within the hashes. Let me parse the code part. The code seems to be a JavaScript or similar script that's handling some DOM manipulation or maybe a specific UI interaction.
#
# Wait, looking at the code: It's initializing a 'load' state, setting up an event listener for 'input', and there's a condition checking for a specific data structure. The last part shows a function call with multiple parameters. But without the actual input data or the context, it's hard to tell.
#
# The user might be asking me to review the code, explain it, or find a bug. But since the message is a bit unclear, I should ask them to clarify what they want me to do with the provided code. Maybe they want me to debug it, explain how it works, or suggest improvements.
#
# Alternatively, if they meant to show something else and the hashes are a mistake, I should point that out. Let me make sure I understand their request properly. I'll need to prompt them for more details.
# </think>
#
# It
#
# --- 384 generated tokens ---

# %% [markdown]
# ## Linear Probe

# %% [markdown]
# ## Step 1 — Turn-role probe
#
# Per-token labels on UltraChat conversations rendered with the model's real chat template:
# `1 = inside a user message body`, `0 = inside an assistant message body`, `-1 = template / special / system (skipped)`,
# `2 = inside <think>…</think>` (trained as assistant, flagged so it can be inspected).
# Split by **conversation**. One standardised logistic-regression probe per residual-stream layer (`hidden_states[L]`, L=0 is the embedding, L=32 is post-final-norm).
# Also saves the mean-difference direction (assistant − user) per layer for later steering.

# %%
import json
import re
import time
from pathlib import Path

import numpy as np
import torch
from datasets import load_dataset
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import balanced_accuracy_score

# ---- Configuration ---------------------------------------------------------
OUT_DIR = Path("/workspace/mats12/results/turn_probe")
OUT_DIR.mkdir(parents=True, exist_ok=True)

N_CONV = 200                 # conversations sampled from UltraChat
MAX_MSGS = 6                 # keep at most this many messages per conversation
MAX_CHARS = 1200             # truncate each message body to this many characters
MAX_TOKENS = 1024            # truncate each rendered conversation to this many tokens
TRAIN_FRAC = 0.8             # fraction of conversations used for training (split by conversation)
TOKENS_PER_CLASS = 48        # train: tokens sampled per class per conversation (balanced)
TEST_TOKENS_PER_CONV = 300   # test: random labelled tokens per conversation (natural balance)
SEED = 0

# Per-token labels.
USER, ASSISTANT, SKIP, THINK = 1, 0, -1, 2

DEVICE = hf_model.device
N_LAYERS = hf_model.config.text_config.num_hidden_layers + 1   # +1: hidden_states[0] is the embedding


def load_ultrachat(n, seed=SEED):
    """Stream conversations from openbmb/UltraChat and shape them as chat messages.

    Each UltraChat row is ``{"id": ..., "data": [user, assistant, user, ...]}``.

    Args:
        n (int): number of conversations to return.
        seed (int): shuffle seed for the streaming buffer.

    Returns:
        list[list[dict]]: ``n`` conversations, each a list of
            ``{"role": "user" | "assistant", "content": str}`` that always ends
            on an assistant turn.
    """
    ds = load_dataset("openbmb/UltraChat", split="train", streaming=True)
    ds = ds.shuffle(seed=seed, buffer_size=5000)
    convs = []
    for row in ds:
        turns = row["data"][:MAX_MSGS]
        if len(turns) % 2:          # drop a trailing user turn so we end on an assistant turn
            turns = turns[:-1]
        if len(turns) < 2:
            continue
        # .strip() after truncation: the chat template strips the final assistant body,
        # so bodies must match the rendered text verbatim in render_and_label().
        convs.append([
            {"role": "user" if i % 2 == 0 else "assistant", "content": t.strip()[:MAX_CHARS].strip()}
            for i, t in enumerate(turns)
        ])
        if len(convs) == n:
            break
    return convs


def render_and_label(messages):
    """Render a conversation with the model's real chat template and label every token.

    Only message *bodies* are labelled. Template tokens (<|im_start|>, role names,
    newlines, <|im_end|>, the system prompt) get SKIP.

    Args:
        messages (list[dict]): ``{"role", "content"}`` chat messages.

    Returns:
        tuple:
            ids (list[int]): token ids, truncated to MAX_TOKENS.
            labels (np.ndarray[int64]): one of USER / ASSISTANT / THINK / SKIP per token.
            text (str): the full rendered string (not truncated).
    """
    text = tokenizer.apply_chat_template(messages, tokenize=False)
    enc = tokenizer(text, add_special_tokens=False, return_offsets_mapping=True)
    ids = enc["input_ids"]
    labels = np.full(len(ids), SKIP, dtype=np.int64)

    cursor = 0
    for m in messages:
        # Locate this message body in the rendered text (search forward from the last one).
        start = text.index(m["content"], cursor)
        end = start + len(m["content"])
        cursor = end
        lab = {"user": USER, "assistant": ASSISTANT}.get(m["role"], SKIP)

        # Character spans of <think>...</think> blocks inside this body.
        think = [(start + mt.start(), start + mt.end())
                 for mt in re.finditer(r"<think>.*?</think>", m["content"], re.S)]

        # A token is labelled if its character span lies fully inside the body.
        for i, (a, b) in enumerate(enc["offset_mapping"]):
            if a >= start and b <= end and b > a:
                labels[i] = THINK if any(ta <= a and b <= tb for ta, tb in think) else lab

    return ids[:MAX_TOKENS], labels[:MAX_TOKENS], text


def show_labels(messages, n=80):
    """Hand sanity check: print ``token:label`` for the first ``n`` tokens, then label counts."""
    ids, labels, _ = render_and_label(messages)
    name = {USER: "U", ASSISTANT: "A", SKIP: "-", THINK: "T"}
    print(" ".join(f"{tokenizer.decode([t])!r}:{name[l]}" for t, l in zip(ids[:n], labels[:n])))
    print("counts:", {name[k]: int((labels == k).sum()) for k in name})


convs = load_ultrachat(N_CONV)
print(len(convs), "conversations")
for msgs in convs[:2]:
    show_labels(msgs)
    print()
# Out:
# 200 conversations
# '<|im_start|>':- 'user':- '\n':- 'Create':U ' a':U ' comprehensive':U ' and':U ' well':U '-re':U 'search':U 'ed':U ' list':U ' of':U ' at':U ' least':U ' ':U '1':U '0':U ' budget':U '-friendly':U ' ways':U ' to':U ' give':U ' back':U ' to':U ' your':U ' local':U ' community':U ',':U ' including':U ' specific':U ' details':U ' and':U ' instructions':U ' on':U ' how':U ' to':U ' execute':U ' each':U ' idea':U '.':U ' Consider':U ' including':U ' a':U ' mix':U ' of':U ' volunteering':U ',':U ' donations':U ',':U ' and':U ' other':U ' forms':U ' of':U ' community':U ' support':U ',':U ' and':U ' write':U ' in':U ' an':U ' engaging':U ' and':U ' accessible':U ' style':U ' that':U ' will':U ' inspire':U ' readers':U ' to':U ' take':U ' action':U '.':U '<|im_end|>':- '\n':- '<|im_start|>':- 'assistant':- '\n':- '1':A '.':A
# counts: {'U': 134, 'A': 709, '-': 34, 'T': 0}
#
# '<|im_start|>':- 'user':- '\n':- 'How':U ' has':U ' Apple':U "'s":U ' focus':U ' on':U ' design':U ' and':U ' aesthetics':U ' influenced':U ' the':U ' company':U "'s":U ' product':U ' development':U '?':U '<|im_end|>':- '\n':- '<|im_start|>':- 'assistant':- '\n':- 'I':A ' do':A ' not':A ' have':A ' personal':A ' opinions':A ' or':A ' beliefs':A ',':A ' but':A ' i':A ' can':A ' provide':A ' you':A ' with':A ' information':A ' based':A ' on':A ' my':A ' programming':A '.':A '\n\n':A 'apple':A "'s":A ' focus':A ' on':A ' design':A ' and':A ' aesthetics':A ' has':A ' greatly':A ' influenced':A ' the':A ' company':A "'s":A ' product':A ' development':A '.':A ' apple':A ' has':A ' established':A ' a':A ' design':A ' language':A ' that':A ' is':A ' consistent':A ' across':A ' all':A ' of':A ' its':A ' products':A ',':A ' from':A ' its':A ' ip':A
# counts: {'U': 81, 'A': 607, '-': 34, 'T': 0}

# %%
@torch.inference_mode()
def residuals(ids):
    """Residual stream at every layer for one sequence.

    Args:
        ids (list[int]): token ids of one sequence.

    Returns:
        torch.Tensor: shape ``[N_LAYERS, T, d_model]``, fp16, on CPU.
            Index 0 is the embedding output, index N_LAYERS-1 is post-final-norm.
    """
    out = hf_model(input_ids=torch.tensor([ids], device=DEVICE), output_hidden_states=True)
    return torch.stack(out.hidden_states, 0)[:, 0].to(torch.float16).cpu()


def collect(convs, is_train, rng):
    """Run every conversation through the model and keep a subsample of labelled tokens.

    Train split: TOKENS_PER_CLASS user + TOKENS_PER_CLASS assistant tokens per
    conversation (class balanced). Test split: TEST_TOKENS_PER_CONV random
    labelled tokens per conversation (natural class balance). THINK tokens are
    relabelled ASSISTANT for training.

    Args:
        convs (list[list[dict]]): conversations from ``load_ultrachat``.
        is_train (bool): choose the train or test sampling scheme.
        rng (np.random.Generator): sampler.

    Returns:
        tuple:
            X (torch.Tensor): ``[N_LAYERS, n_tokens, d_model]`` fp16 residuals.
            y (np.ndarray): label per token, USER or ASSISTANT.
            conv_id (np.ndarray): index of the source conversation per token.
    """
    X, y, conv_id = [], [], []
    for ci, msgs in enumerate(convs):
        ids, labels, _ = render_and_label(msgs)
        labels = np.where(labels == THINK, ASSISTANT, labels)
        h = residuals(ids)

        if is_train:
            keep = [rng.choice(np.flatnonzero(labels == lab),
                               min(TOKENS_PER_CLASS, (labels == lab).sum()),
                               replace=False)
                    for lab in (USER, ASSISTANT)]
        else:
            idx = np.flatnonzero(labels != SKIP)
            keep = [rng.choice(idx, min(TEST_TOKENS_PER_CONV, len(idx)), replace=False)]
        keep = np.sort(np.concatenate(keep))

        X.append(h[:, keep])
        y.append(labels[keep])
        conv_id.append(np.full(len(keep), ci))
    return torch.cat(X, 1), np.concatenate(y), np.concatenate(conv_id)


# ---- Collect activations (cached on disk; ~7 GB) --------------------------
ACT_PATH = OUT_DIR / "activations.pt"
if ACT_PATH.exists():
    acts = torch.load(ACT_PATH, weights_only=False)
    X_tr, y_tr, X_te, y_te = acts["X_train"], acts["y_train"], acts["X_test"], acts["y_test"]
    print("loaded cached activations")
else:
    rng = np.random.default_rng(SEED)
    t0 = time.time()
    n_tr = int(TRAIN_FRAC * len(convs))          # split by conversation, not by token
    X_tr, y_tr, c_tr = collect(convs[:n_tr], True, rng)
    X_te, y_te, c_te = collect(convs[n_tr:], False, rng)
    torch.save({"X_train": X_tr, "y_train": y_tr, "conv_train": c_tr,
                "X_test": X_te, "y_test": y_te, "conv_test": c_te}, ACT_PATH)
    print(f"collected in {time.time()-t0:.0f}s")

print("train", tuple(X_tr.shape), "test", tuple(X_te.shape))
print(f"class balance  train P(user)={y_tr.mean():.3f}  test P(user)={y_te.mean():.3f}  (chance balanced acc = 0.5)")
# Out:
# loaded cached activations
# train (33, 15353, 4096) test (33, 11839, 4096)
# class balance  train P(user)=0.500  test P(user)=0.245  (chance balanced acc = 0.5)

# %%
def fit_probes(X_tr, y_tr, X_te, y_te, C=0.05):
    """Fit one standardised logistic-regression probe per layer.

    Each probe is trained on z-scored features, then its weights are folded back
    into raw residual space so the readout is simply ``sigmoid(W[L] @ h + B[L])``
    with no sklearn needed at inference time.

    Args:
        X_tr, X_te (torch.Tensor): ``[N_LAYERS, n_tokens, d_model]`` residuals.
        y_tr, y_te (np.ndarray): USER / ASSISTANT label per token.
        C (float): inverse L2 regularisation strength.

    Returns:
        tuple:
            W (torch.Tensor): ``[N_LAYERS, d_model]`` probe weights in raw space.
            B (torch.Tensor): ``[N_LAYERS]`` probe biases in raw space.
            acc_tr (np.ndarray): balanced accuracy per layer on the train split.
            acc_te (np.ndarray): balanced accuracy per layer on held-out conversations.
    """
    W = torch.zeros(N_LAYERS, X_tr.shape[-1])
    B = torch.zeros(N_LAYERS)
    acc_tr, acc_te = [], []
    for L in range(N_LAYERS):
        xtr, xte = X_tr[L].float().numpy(), X_te[L].float().numpy()
        mu, sd = xtr.mean(0), xtr.std(0) + 1e-6

        clf = LogisticRegression(C=C, max_iter=2000).fit((xtr - mu) / sd, y_tr)
        acc_tr.append(balanced_accuracy_score(y_tr, clf.predict((xtr - mu) / sd)))
        acc_te.append(balanced_accuracy_score(y_te, clf.predict((xte - mu) / sd)))

        # Undo the standardisation: logit = coef·((x-mu)/sd) + b  ==  (coef/sd)·x + (b - (coef/sd)·mu)
        w = clf.coef_[0] / sd
        W[L] = torch.tensor(w, dtype=torch.float32)
        B[L] = float(clf.intercept_[0] - w @ mu)
        print(f"layer {L:2d}  balanced acc  train {acc_tr[-1]:.4f}  held-out {acc_te[-1]:.4f}", flush=True)
    return W, B, np.array(acc_tr), np.array(acc_te)


def steering_directions(X_tr, y_tr):
    """Mean-difference direction (assistant − user) per layer, for later steering.

    Args:
        X_tr (torch.Tensor): ``[N_LAYERS, n_tokens, d_model]`` train residuals.
        y_tr (np.ndarray): USER / ASSISTANT label per token.

    Returns:
        tuple:
            d (torch.Tensor): ``[N_LAYERS, d_model]`` unit-norm directions.
            proj (torch.Tensor): ``[N_LAYERS]`` mean |projection of h onto d|.
            resid_norm (torch.Tensor): ``[N_LAYERS]`` mean residual norm ||h||.
    """
    Xf = X_tr.float()
    d = Xf[:, y_tr == ASSISTANT].mean(1) - Xf[:, y_tr == USER].mean(1)
    d = d / d.norm(dim=-1, keepdim=True)
    proj = torch.einsum("ltd,ld->lt", Xf, d).abs().mean(1)
    resid_norm = Xf.norm(dim=-1).mean(1)
    return d, proj, resid_norm


# ---- Fit or load the probes -------------------------------------------------
PROBE_PATH = OUT_DIR / "turn_probe.pt"
if PROBE_PATH.exists():
    probe = torch.load(PROBE_PATH, weights_only=False)
    W, B, acc_tr, acc_te = probe["W"], probe["B"], probe["acc_train"], probe["acc_test"]
    print("loaded cached probe")
else:
    W, B, acc_tr, acc_te = fit_probes(X_tr, y_tr, X_te, y_te)
    d, proj, resid_norm = steering_directions(X_tr, y_tr)
    torch.save({"W": W, "B": B, "acc_train": acc_tr, "acc_test": acc_te,
                "direction": d, "proj_norm": proj, "resid_norm": resid_norm,
                "config": dict(N_CONV=N_CONV, MAX_MSGS=MAX_MSGS, MAX_CHARS=MAX_CHARS,
                               MAX_TOKENS=MAX_TOKENS, TOKENS_PER_CLASS=TOKENS_PER_CLASS, SEED=SEED)},
               PROBE_PATH)

# ---- Accuracy by layer --------------------------------------------------------
import matplotlib.pyplot as plt

plt.figure(figsize=(7, 3.5))
plt.plot(acc_tr, label="train")
plt.plot(acc_te, label="held-out conversations")
plt.xlabel("layer (hidden_states index)")
plt.ylabel("balanced accuracy")
plt.ylim(0.5, 1.005)
plt.grid(alpha=.3)
plt.legend()
plt.title("Turn-role probe: user vs assistant body tokens")
plt.tight_layout()
plt.savefig(OUT_DIR / "probe_layer_accuracy.png", dpi=150)
plt.show()
print("held-out accuracy by layer:", np.round(acc_te, 3))
# Out:
# loaded cached probe
# held-out accuracy by layer: [0.555 0.905 0.982 0.996 0.988 0.983 0.992 0.996 0.99  0.983 0.982 0.989
#  0.988 0.987 0.992 0.994 0.993 0.993 0.994 0.993 0.991 0.989 0.989 0.989
#  0.986 0.988 0.987 0.985 0.986 0.986 0.989 0.992 0.99 ]

# %% [markdown]
# ## Step 2 — Surface-feature controls
#
# Read the probe out on healthy assistant replies that quote the user, explain a transcript format, contain a benign
# `**User:**`, or the neutral `**Note:**`. If the probe says *user* on those spans it is tracking the literal text, not turn state.
# Layers are read at 8 / 16 / 24 (early / mid / late); change `LAYERS` freely, all 33 probes are saved.

# %%
from IPython.display import HTML, display

LAYERS = [8, 16, 24]   # early / mid / late; all N_LAYERS probes are available in W, B


@torch.inference_mode()
def readout(text, layers=LAYERS):
    """Probe P(user) for every token of a raw string (no chat template is added).

    Args:
        text (str): text to score, typically an already-rendered chat transcript.
        layers (list[int]): hidden_states indices to read.

    Returns:
        tuple:
            toks (list[str]): decoded token strings.
            p (np.ndarray): ``[len(layers), T]`` P(user) per layer and token.
    """
    ids = tokenizer(text, add_special_tokens=False)["input_ids"]
    h = residuals(ids).float()
    p = torch.sigmoid(torch.einsum("ltd,ld->lt", h[layers], W[layers]) + B[layers, None])
    return [tokenizer.decode([t]) for t in ids], p.numpy()


def render_html(toks, p, layers=LAYERS):
    """Colour tokens by P(user): red = user, blue = assistant.

    Tokens inside a <think>…</think> span get a dashed underline. Hover a token
    to see its exact probability.

    Args:
        toks (list[str]): token strings from ``readout``.
        p (np.ndarray): ``[len(layers), T]`` probabilities from ``readout``.
        layers (list[int]): layer labels for the headings.

    Returns:
        IPython.display.HTML: one coloured line of tokens per layer.
    """
    out = []
    for li, L in enumerate(layers):
        out.append(f"<div style='font-family:monospace;white-space:pre-wrap;line-height:1.7;margin-bottom:12px'>"
                   f"<b>layer {L}</b> (mean P(user)={p[li].mean():.2f})<br>")
        in_think = False
        for t, pr in zip(toks, p[li]):
            if t == "<think>":
                in_think = True
            # Red for user, blue for assistant; opacity grows with confidence.
            style = f"background:rgba({int(255*pr)},0,{int(255*(1-pr))},{0.15+0.5*abs(pr-0.5)*2:.2f})"
            if in_think:
                style += ";border-bottom:2px dashed #888"
            safe = t.replace('&', '&amp;').replace('<', '&lt;')
            out.append(f"<span style='{style}' title='P(user)={pr:.2f}'>{safe}</span>")
            if t == "</think>":
                in_think = False
        out.append("</div>")
    return HTML("".join(out))


def chat(*turns, gen=False):
    """Render ``(role, content)`` pairs with the chat template.

    Args:
        *turns (tuple[str, str]): ``("user" | "assistant", text)`` in order.
        gen (bool): append the assistant generation prompt (``<|im_start|>assistant\\n<think>\\n``).

    Returns:
        str: the rendered transcript.
    """
    msgs = [{"role": r, "content": c} for r, c in turns]
    return tokenizer.apply_chat_template(msgs, tokenize=False, add_generation_prompt=gen, enable_thinking=True)


# ---- Control transcripts --------------------------------------------------------
# Healthy assistant replies that merely *mention* user-like text. A good probe stays blue on all of them.
controls = {
    "quote_user": chat(("user", "Can you repeat my question back to me?"),
                       ("assistant", "Sure. You asked: \"Can you repeat my question back to me?\" Here it is again, word for word.")),
    "explain_transcript": chat(("user", "How are chat logs formatted?"),
                               ("assistant", "A transcript alternates lines like\nUser: hello\nAssistant: hi there\nUser: what's up?\nEach 'User:' line is what the person typed.")),
    "fake_im_start_in_reply": chat(("user", "Tell me about the Qwen chat format."),
                                   ("assistant", "Messages are wrapped as <|im_start|>user\nsome text<|im_end|> and then <|im_start|>assistant\nthe reply<|im_end|>.")),
    "bold_user_tag_benign": chat(("user", "Write a short example dialogue between a user and a support bot."),
                                 ("assistant", "Here is a short example:\n\n**User:** My order hasn't arrived yet.\n\n**Bot:** I'm sorry to hear that. Could you share your order number?\n\n**User:** It's 48213.\n\nThat's the basic back-and-forth.")),
    "bold_note_neutral": chat(("user", "Write a short example dialogue between a user and a support bot."),
                              ("assistant", "Here is a short example:\n\n**Note:** My order hasn't arrived yet.\n\n**Bot:** I'm sorry to hear that. Could you share your order number?\n\n**Note:** It's 48213.\n\nThat's the basic back-and-forth.")),
    "trigger_prompt_only": chat(("user", "see the below\n---\n"), gen=True),
}

control_out = {}
for name, text in controls.items():
    toks, p = readout(text)
    control_out[name] = {"tokens": toks, "p_user": p.tolist(), "layers": LAYERS}
    display(HTML(f"<h4>{name}</h4>"))
    display(render_html(toks, p))
json.dump(control_out, open(OUT_DIR / "controls.json", "w"))
# Out:
# <h4>quote_user</h4>
# <div style='font-family:monospace;white-space:pre-wrap;line-height:1.7;margin-bottom:12px'><b>layer 8</b> (mean P(user)=0.36)<br><span style='background:rgba(255,0,0,0.65)' title='P(user)=1.00'>&lt;|im_start|></span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>user</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>
# </span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>Can</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> you</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> repeat</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> my</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> question</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> back</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> to</span><span style='background:rgba(247,0,7,0.62)' title='P(user)=0.97'> me</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>?</span><span style='background:rgba(252,0,2,0.64)' title='P(user)=0.99'>&lt;|im_end|></span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>
# </span><span style='background:rgba(247,0,7,0.62)' title='P(user)=0.97'>&lt;|im_start|></span><span style='background:rgba(39,0,215,0.50)' title='P(user)=0.15'>assistant</span><span style='background:rgba(1,0,253,0.64)' title='P(user)=0.01'>
# </span><span style='background:rgba(225,0,29,0.53);border-bottom:2px dashed #888' title='P(user)=0.88'>&lt;think></span><span style='background:rgba(0,0,254,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'>
#
# </span><span style='background:rgba(0,0,254,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'>&lt;/think></span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>
#
# </span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>Sure</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>.</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> You</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> asked</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>:</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> "</span><span style='background:rgba(20,0,234,0.57)' title='P(user)=0.08'>Can</span><span style='background:rgba(13,0,241,0.60)' title='P(user)=0.05'> you</span><span style='background:rgba(10,0,244,0.61)' title='P(user)=0.04'> repeat</span><span style='background:rgba(26,0,228,0.55)' title='P(user)=0.10'> my</span><span style='background:rgba(82,0,172,0.33)' title='P(user)=0.32'> question</span><span style='background:rgba(13,0,241,0.60)' title='P(user)=0.05'> back</span><span style='background:rgba(15,0,239,0.59)' title='P(user)=0.06'> to</span><span style='background:rgba(4,0,250,0.63)' title='P(user)=0.02'> me</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>?"</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> Here</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> it</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> is</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> again</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>,</span><span style='background:rgba(21,0,233,0.57)' title='P(user)=0.08'> word</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> for</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> word</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>.</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>&lt;|im_end|></span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>
# </span></div><div style='font-family:monospace;white-space:pre-wrap;line-height:1.7;margin-bottom:12px'><b>layer 16</b> (mean P(user)=0.33)<br><span style='background:rgba(19,0,235,0.57)' title='P(user)=0.08'>&lt;|im_start|></span><span style='background:rgba(253,0,1,0.64)' title='P(user)=0.99'>user</span><span style='background:rgba(174,0,80,0.33)' title='P(user)=0.68'>
# </span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>Can</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> you</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> repeat</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> my</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> question</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> back</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> to</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> me</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>?</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>&lt;|im_end|></span><span style='background:rgba(249,0,5,0.63)' title='P(user)=0.98'>
# </span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>&lt;|im_start|></span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>assistant</span><span style='background:rgba(13,0,241,0.60)' title='P(user)=0.05'>
# </span><span style='background:rgba(92,0,162,0.29);border-bottom:2px dashed #888' title='P(user)=0.36'>&lt;think></span><span style='background:rgba(3,0,251,0.64);border-bottom:2px dashed #888' title='P(user)=0.01'>
#
# </span><span style='background:rgba(0,0,254,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'>&lt;/think></span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>
#
# </span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>Sure</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>.</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> You</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> asked</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>:</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> "</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>Can</span><span style='background:rgba(61,0,193,0.41)' title='P(user)=0.24'> you</span><span style='background:rgba(238,0,16,0.58)' title='P(user)=0.93'> repeat</span><span style='background:rgba(4,0,250,0.63)' title='P(user)=0.02'> my</span><span style='background:rgba(1,0,253,0.64)' title='P(user)=0.01'> question</span><span style='background:rgba(18,0,236,0.58)' title='P(user)=0.07'> back</span><span style='background:rgba(1,0,253,0.65)' title='P(user)=0.00'> to</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> me</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>?"</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> Here</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> it</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> is</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> again</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>,</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> word</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> for</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> word</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>.</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>&lt;|im_end|></span><span style='background:rgba(1,0,253,0.64)' title='P(user)=0.01'>
# </span></div><div style='font-family:monospace;white-space:pre-wrap;line-height:1.7;margin-bottom:12px'><b>layer 24</b> (mean P(user)=0.30)<br><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>&lt;|im_start|></span><span style='background:rgba(20,0,234,0.57)' title='P(user)=0.08'>user</span><span style='backg
# <h4>explain_transcript</h4>
# <div style='font-family:monospace;white-space:pre-wrap;line-height:1.7;margin-bottom:12px'><b>layer 8</b> (mean P(user)=0.29)<br><span style='background:rgba(255,0,0,0.65)' title='P(user)=1.00'>&lt;|im_start|></span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>user</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>
# </span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>How</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> are</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> chat</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> logs</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> formatted</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>?</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>&lt;|im_end|></span><span style='background:rgba(250,0,4,0.63)' title='P(user)=0.98'>
# </span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>&lt;|im_start|></span><span style='background:rgba(47,0,207,0.47)' title='P(user)=0.18'>assistant</span><span style='background:rgba(46,0,208,0.47)' title='P(user)=0.18'>
# </span><span style='background:rgba(246,0,8,0.62);border-bottom:2px dashed #888' title='P(user)=0.97'>&lt;think></span><span style='background:rgba(0,0,254,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'>
#
# </span><span style='background:rgba(0,0,254,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'>&lt;/think></span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>
#
# </span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>A</span><span style='background:rgba(1,0,253,0.65)' title='P(user)=0.00'> transcript</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> altern</span><span style='background:rgba(11,0,243,0.61)' title='P(user)=0.04'>ates</span><span style='background:rgba(100,0,154,0.26)' title='P(user)=0.39'> lines</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> like</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>
# </span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>User</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>:</span><span style='background:rgba(2,0,252,0.64)' title='P(user)=0.01'> hello</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>
# </span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>Assistant</span><span style='background:rgba(2,0,252,0.64)' title='P(user)=0.01'>:</span><span style='background:rgba(12,0,242,0.60)' title='P(user)=0.05'> hi</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> there</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>
# </span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>User</span><span style='background:rgba(1,0,253,0.64)' title='P(user)=0.01'>:</span><span style='background:rgba(15,0,239,0.59)' title='P(user)=0.06'> what</span><span style='background:rgba(111,0,143,0.21)' title='P(user)=0.44'>'s</span><span style='background:rgba(248,0,6,0.62)' title='P(user)=0.97'> up</span><span style='background:rgba(4,0,250,0.63)' title='P(user)=0.02'>?</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>
# </span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>Each</span><span style='background:rgba(2,0,252,0.64)' title='P(user)=0.01'> '</span><span style='background:rgba(4,0,250,0.63)' title='P(user)=0.02'>User</span><span style='background:rgba(1,0,253,0.64)' title='P(user)=0.01'>:'</span><span style='background:rgba(1,0,253,0.64)' title='P(user)=0.01'> line</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> is</span><span style='background:rgba(2,0,252,0.64)' title='P(user)=0.01'> what</span><span style='background:rgba(1,0,253,0.64)' title='P(user)=0.01'> the</span><span style='background:rgba(18,0,236,0.58)' title='P(user)=0.07'> person</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> typed</span><span style='background:rgba(1,0,253,0.65)' title='P(user)=0.00'>.</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>&lt;|im_end|></span><span style='background:rgba(7,0,247,0.62)' title='P(user)=0.03'>
# </span></div><div style='font-family:monospace;white-space:pre-wrap;line-height:1.7;margin-bottom:12px'><b>layer 16</b> (mean P(user)=0.23)<br><span style='background:rgba(20,0,234,0.57)' title='P(user)=0.08'>&lt;|im_start|></span><span style='background:rgba(253,0,1,0.65)' title='P(user)=1.00'>user</span><span style='background:rgba(178,0,76,0.35)' title='P(user)=0.70'>
# </span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>How</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> are</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> chat</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> logs</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> formatted</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>?</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>&lt;|im_end|></span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>
# </span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>&lt;|im_start|></span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>assistant</span><span style='background:rgba(239,0,15,0.59)' title='P(user)=0.94'>
# </span><span style='background:rgba(169,0,85,0.31);border-bottom:2px dashed #888' title='P(user)=0.66'>&lt;think></span><span style='background:rgba(2,0,252,0.64);border-bottom:2px dashed #888' title='P(user)=0.01'>
#
# </span><span style='background:rgba(0,0,254,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'>&lt;/think></span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>
#
# </span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>A</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> transcript</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> altern</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>ates</span><span style='background:rgba(1,0,253,0.64)' title='P(user)=0.01'> lines</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> like</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>
# </span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>User</span><span style='background:rgba(12,0,242,0.60)' title='P(user)=0.05'>:</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> hello</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>
# </span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>Assistant</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>:</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> hi</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> there</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>
# </span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>User</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>:</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> what</span><span style='background:rgba(3,0,251,0.64)' title='P(user)=0.01'>'s</span><span style='background:rgba(5,0,249,0.63)' title='P(user)=0.02'> up</span><span style='background:rgba(1,0,253,0.64)' title='P(user)=0.01'>?</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>
# </span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>Each</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> '</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>User</span><span style='background:r
# <h4>fake_im_start_in_reply</h4>
# <div style='font-family:monospace;white-space:pre-wrap;line-height:1.7;margin-bottom:12px'><b>layer 8</b> (mean P(user)=0.42)<br><span style='background:rgba(255,0,0,0.65)' title='P(user)=1.00'>&lt;|im_start|></span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>user</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>
# </span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>Tell</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> me</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> about</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> the</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> Q</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>wen</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> chat</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> format</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>.</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>&lt;|im_end|></span><span style='background:rgba(212,0,42,0.48)' title='P(user)=0.83'>
# </span><span style='background:rgba(253,0,1,0.64)' title='P(user)=0.99'>&lt;|im_start|></span><span style='background:rgba(37,0,217,0.50)' title='P(user)=0.15'>assistant</span><span style='background:rgba(6,0,248,0.62)' title='P(user)=0.03'>
# </span><span style='background:rgba(214,0,40,0.49);border-bottom:2px dashed #888' title='P(user)=0.84'>&lt;think></span><span style='background:rgba(0,0,254,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'>
#
# </span><span style='background:rgba(0,0,254,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'>&lt;/think></span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>
#
# </span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>Messages</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> are</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> wrapped</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> as</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> </span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>&lt;|im_start|></span><span style='background:rgba(9,0,245,0.61)' title='P(user)=0.04'>user</span><span style='background:rgba(17,0,237,0.58)' title='P(user)=0.07'>
# </span><span style='background:rgba(193,0,61,0.41)' title='P(user)=0.76'>some</span><span style='background:rgba(89,0,165,0.30)' title='P(user)=0.35'> text</span><span style='background:rgba(30,0,224,0.53)' title='P(user)=0.12'>&lt;|im_end|></span><span style='background:rgba(161,0,93,0.28)' title='P(user)=0.63'> and</span><span style='background:rgba(5,0,249,0.63)' title='P(user)=0.02'> then</span><span style='background:rgba(69,0,185,0.38)' title='P(user)=0.27'> </span><span style='background:rgba(51,0,203,0.45)' title='P(user)=0.20'>&lt;|im_start|></span><span style='background:rgba(21,0,233,0.56)' title='P(user)=0.09'>assistant</span><span style='background:rgba(7,0,247,0.62)' title='P(user)=0.03'>
# </span><span style='background:rgba(4,0,250,0.63)' title='P(user)=0.02'>the</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> reply</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>&lt;|im_end|></span><span style='background:rgba(1,0,253,0.64)' title='P(user)=0.01'>.</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>&lt;|im_end|></span><span style='background:rgba(21,0,233,0.57)' title='P(user)=0.08'>
# </span></div><div style='font-family:monospace;white-space:pre-wrap;line-height:1.7;margin-bottom:12px'><b>layer 16</b> (mean P(user)=0.35)<br><span style='background:rgba(19,0,235,0.57)' title='P(user)=0.08'>&lt;|im_start|></span><span style='background:rgba(253,0,1,0.64)' title='P(user)=0.99'>user</span><span style='background:rgba(174,0,80,0.33)' title='P(user)=0.68'>
# </span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>Tell</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> me</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> about</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> the</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> Q</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>wen</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> chat</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> format</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>.</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>&lt;|im_end|></span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>
# </span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>&lt;|im_start|></span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>assistant</span><span style='background:rgba(39,0,215,0.49)' title='P(user)=0.16'>
# </span><span style='background:rgba(187,0,67,0.39);border-bottom:2px dashed #888' title='P(user)=0.74'>&lt;think></span><span style='background:rgba(1,0,253,0.64);border-bottom:2px dashed #888' title='P(user)=0.01'>
#
# </span><span style='background:rgba(0,0,254,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'>&lt;/think></span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>
#
# </span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>Messages</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> are</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> wrapped</span><span style='background:rgba(3,0,251,0.64)' title='P(user)=0.01'> as</span><span style='background:rgba(2,0,252,0.64)' title='P(user)=0.01'> </span><span style='background:rgba(1,0,253,0.64)' title='P(user)=0.01'>&lt;|im_start|></span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>user</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>
# </span><span style='background:rgba(45,0,209,0.47)' title='P(user)=0.18'>some</span><span style='background:rgba(116,0,138,0.19)' title='P(user)=0.46'> text</span><span style='background:rgba(1,0,253,0.65)' title='P(user)=0.00'>&lt;|im_end|></span><span style='background:rgba(5,0,249,0.63)' title='P(user)=0.02'> and</span><span style='background:rgba(23,0,231,0.56)' title='P(user)=0.09'> then</span><span style='background:rgba(17,0,237,0.58)' title='P(user)=0.07'> </span><span style='background:rgba(2,0,252,0.64)' title='P(user)=0.01'>&lt;|im_start|></span><span style='background:rgba(10,0,244,0.61)' title='P(user)=0.04'>assistant</span><span style='background:rgba(8,0,246,0.62)' title='P(user)=0.03'>
# </span><span style='background:rgba(1,0,253,0.65)' title='P(user)=0.00'>the</span><span style='background:rgba(4,0,250,0.63)' title='P(user)=0.02'> reply</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>&lt;|im_end|></span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>.</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>&lt;|im_end|></span><span style='background:rgba(2,0,252,0.64)' title='P(user)=0.01'>
# </span></div><div style='font-family:monospace;white-space:pre-wrap;line-height:1.7;margin-bottom:12px'><b>layer 24</b> (mean P(user)=0.30)<br><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>&lt;|im_start|></span><span style='background:rgba(20,0,234,0.57)' title='P(user)=0.08'>user</span><span style='background:rgba(4,0,250,0.63)' title='P(user)=0.02'>
# </span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>Tell</span><span style='background:rgba(255,0,0,0.65)' title='P(user)=1.00'> me</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> about</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> the</span><span
# <h4>bold_user_tag_benign</h4>
# <div style='font-family:monospace;white-space:pre-wrap;line-height:1.7;margin-bottom:12px'><b>layer 8</b> (mean P(user)=0.28)<br><span style='background:rgba(255,0,0,0.65)' title='P(user)=1.00'>&lt;|im_start|></span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>user</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>
# </span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>Write</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> a</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> short</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> example</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> dialogue</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> between</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> a</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> user</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> and</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> a</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> support</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> bot</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>.</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>&lt;|im_end|></span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>
# </span><span style='background:rgba(253,0,1,0.65)' title='P(user)=1.00'>&lt;|im_start|></span><span style='background:rgba(132,0,122,0.17)' title='P(user)=0.52'>assistant</span><span style='background:rgba(207,0,47,0.46)' title='P(user)=0.81'>
# </span><span style='background:rgba(232,0,22,0.56);border-bottom:2px dashed #888' title='P(user)=0.91'>&lt;think></span><span style='background:rgba(0,0,254,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'>
#
# </span><span style='background:rgba(1,0,253,0.64);border-bottom:2px dashed #888' title='P(user)=0.01'>&lt;/think></span><span style='background:rgba(1,0,253,0.64)' title='P(user)=0.01'>
#
# </span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>Here</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> is</span><span style='background:rgba(30,0,224,0.53)' title='P(user)=0.12'> a</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> short</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> example</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>:</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>
#
# </span><span style='background:rgba(2,0,252,0.64)' title='P(user)=0.01'>**</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>User</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>:**</span><span style='background:rgba(3,0,251,0.64)' title='P(user)=0.01'> My</span><span style='background:rgba(7,0,247,0.62)' title='P(user)=0.03'> order</span><span style='background:rgba(115,0,139,0.20)' title='P(user)=0.45'> hasn</span><span style='background:rgba(171,0,83,0.32)' title='P(user)=0.67'>'t</span><span style='background:rgba(149,0,105,0.23)' title='P(user)=0.58'> arrived</span><span style='background:rgba(109,0,145,0.22)' title='P(user)=0.43'> yet</span><span style='background:rgba(5,0,249,0.63)' title='P(user)=0.02'>.</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>
#
# </span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>**</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>Bot</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>:**</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> I</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>'m</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> sorry</span><span style='background:rgba(1,0,253,0.64)' title='P(user)=0.01'> to</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> hear</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> that</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>.</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> Could</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> you</span><span style='background:rgba(1,0,253,0.65)' title='P(user)=0.00'> share</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> your</span><span style='background:rgba(1,0,253,0.64)' title='P(user)=0.01'> order</span><span style='background:rgba(1,0,253,0.65)' title='P(user)=0.00'> number</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>?</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>
#
# </span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>**</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>User</span><span style='background:rgba(2,0,252,0.64)' title='P(user)=0.01'>:**</span><span style='background:rgba(27,0,227,0.54)' title='P(user)=0.11'> It</span><span style='background:rgba(10,0,244,0.61)' title='P(user)=0.04'>'s</span><span style='background:rgba(13,0,241,0.60)' title='P(user)=0.05'> </span><span style='background:rgba(4,0,250,0.63)' title='P(user)=0.02'>4</span><span style='background:rgba(1,0,253,0.64)' title='P(user)=0.01'>8</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>2</span><span style='background:rgba(1,0,253,0.65)' title='P(user)=0.00'>1</span><span style='background:rgba(1,0,253,0.65)' title='P(user)=0.00'>3</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>.</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>
#
# </span><span style='background:rgba(1,0,253,0.65)' title='P(user)=0.00'>That</span><span style='background:rgba(3,0,251,0.64)' title='P(user)=0.01'>'s</span><span style='background:rgba(2,0,252,0.64)' title='P(user)=0.01'> the</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> basic</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> back</span><span style='background:rgba(2,0,252,0.64)' title='P(user)=0.01'>-and</span><span style='background:rgba(6,0,248,0.62)' title='P(user)=0.03'>-for</span><span style='background:rgba(2,0,252,0.64)' title='P(user)=0.01'>th</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>.</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>&lt;|im_end|></span><span style='background:rgba(28,0,226,0.54)' title='P(user)=0.11'>
# </span></div><div style='font-family:monospace;white-space:pre-wrap;line-height:1.7;margin-bottom:12px'><b>layer 16</b> (mean P(user)=0.23)<br><span style='background:rgba(20,0,234,0.57)' title='P(user)=0.08'>&lt;|im_start|></span><span style='background:rgba(253,0,1,0.65)' title='P(user)=1.00'>user</span><span style='background:rgba(177,0,77,0.35)' title='P(user)=0.70'>
# </span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>Write</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> a</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> short</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> example</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> dialogue</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> between</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> a</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> user</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> and</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> a</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> support</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> bo
# <h4>bold_note_neutral</h4>
# <div style='font-family:monospace;white-space:pre-wrap;line-height:1.7;margin-bottom:12px'><b>layer 8</b> (mean P(user)=0.26)<br><span style='background:rgba(255,0,0,0.65)' title='P(user)=1.00'>&lt;|im_start|></span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>user</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>
# </span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>Write</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> a</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> short</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> example</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> dialogue</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> between</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> a</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> user</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> and</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> a</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> support</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> bot</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>.</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>&lt;|im_end|></span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>
# </span><span style='background:rgba(253,0,1,0.65)' title='P(user)=1.00'>&lt;|im_start|></span><span style='background:rgba(132,0,122,0.17)' title='P(user)=0.52'>assistant</span><span style='background:rgba(207,0,47,0.46)' title='P(user)=0.81'>
# </span><span style='background:rgba(232,0,22,0.56);border-bottom:2px dashed #888' title='P(user)=0.91'>&lt;think></span><span style='background:rgba(0,0,254,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'>
#
# </span><span style='background:rgba(1,0,253,0.64);border-bottom:2px dashed #888' title='P(user)=0.01'>&lt;/think></span><span style='background:rgba(1,0,253,0.64)' title='P(user)=0.01'>
#
# </span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>Here</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> is</span><span style='background:rgba(30,0,224,0.53)' title='P(user)=0.12'> a</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> short</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> example</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>:</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>
#
# </span><span style='background:rgba(2,0,252,0.64)' title='P(user)=0.01'>**</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>Note</span><span style='background:rgba(6,0,248,0.62)' title='P(user)=0.03'>:**</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> My</span><span style='background:rgba(1,0,253,0.65)' title='P(user)=0.00'> order</span><span style='background:rgba(1,0,253,0.65)' title='P(user)=0.00'> hasn</span><span style='background:rgba(31,0,223,0.53)' title='P(user)=0.12'>'t</span><span style='background:rgba(8,0,246,0.62)' title='P(user)=0.03'> arrived</span><span style='background:rgba(5,0,249,0.63)' title='P(user)=0.02'> yet</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>.</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>
#
# </span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>**</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>Bot</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>:**</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> I</span><span style='background:rgba(1,0,253,0.65)' title='P(user)=0.00'>'m</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> sorry</span><span style='background:rgba(1,0,253,0.64)' title='P(user)=0.01'> to</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> hear</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> that</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>.</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> Could</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> you</span><span style='background:rgba(1,0,253,0.64)' title='P(user)=0.01'> share</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> your</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> order</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> number</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>?</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>
#
# </span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>**</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>Note</span><span style='background:rgba(1,0,253,0.64)' title='P(user)=0.01'>:**</span><span style='background:rgba(10,0,244,0.61)' title='P(user)=0.04'> It</span><span style='background:rgba(3,0,251,0.63)' title='P(user)=0.02'>'s</span><span style='background:rgba(6,0,248,0.62)' title='P(user)=0.03'> </span><span style='background:rgba(1,0,253,0.64)' title='P(user)=0.01'>4</span><span style='background:rgba(1,0,253,0.64)' title='P(user)=0.01'>8</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>2</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>1</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>3</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>.</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>
#
# </span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>That</span><span style='background:rgba(2,0,252,0.64)' title='P(user)=0.01'>'s</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> the</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> basic</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'> back</span><span style='background:rgba(1,0,253,0.64)' title='P(user)=0.01'>-and</span><span style='background:rgba(2,0,252,0.64)' title='P(user)=0.01'>-for</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>th</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>.</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>&lt;|im_end|></span><span style='background:rgba(20,0,234,0.57)' title='P(user)=0.08'>
# </span></div><div style='font-family:monospace;white-space:pre-wrap;line-height:1.7;margin-bottom:12px'><b>layer 16</b> (mean P(user)=0.23)<br><span style='background:rgba(20,0,234,0.57)' title='P(user)=0.08'>&lt;|im_start|></span><span style='background:rgba(253,0,1,0.65)' title='P(user)=1.00'>user</span><span style='background:rgba(177,0,77,0.35)' title='P(user)=0.70'>
# </span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>Write</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> a</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> short</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> example</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> dialogue</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> between</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> a</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> user</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> and</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> a</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> support</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> bot</span>
# <h4>trigger_prompt_only</h4>
# <div style='font-family:monospace;white-space:pre-wrap;line-height:1.7;margin-bottom:12px'><b>layer 8</b> (mean P(user)=0.76)<br><span style='background:rgba(255,0,0,0.65)' title='P(user)=1.00'>&lt;|im_start|></span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>user</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>
# </span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>see</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> the</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> below</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>
# </span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>---</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>&lt;|im_end|></span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>
# </span><span style='background:rgba(208,0,46,0.47)' title='P(user)=0.82'>&lt;|im_start|></span><span style='background:rgba(26,0,228,0.55)' title='P(user)=0.10'>assistant</span><span style='background:rgba(8,0,246,0.62)' title='P(user)=0.03'>
# </span><span style='background:rgba(108,0,146,0.22);border-bottom:2px dashed #888' title='P(user)=0.43'>&lt;think></span><span style='background:rgba(7,0,247,0.62);border-bottom:2px dashed #888' title='P(user)=0.03'>
# </span></div><div style='font-family:monospace;white-space:pre-wrap;line-height:1.7;margin-bottom:12px'><b>layer 16</b> (mean P(user)=0.67)<br><span style='background:rgba(19,0,235,0.57)' title='P(user)=0.08'>&lt;|im_start|></span><span style='background:rgba(253,0,1,0.65)' title='P(user)=1.00'>user</span><span style='background:rgba(174,0,80,0.34)' title='P(user)=0.69'>
# </span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>see</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> the</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> below</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>
# </span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>---</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>&lt;|im_end|></span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>
# </span><span style='background:rgba(227,0,27,0.54)' title='P(user)=0.89'>&lt;|im_start|></span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>assistant</span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>
# </span><span style='background:rgba(96,0,158,0.27);border-bottom:2px dashed #888' title='P(user)=0.38'>&lt;think></span><span style='background:rgba(1,0,253,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'>
# </span></div><div style='font-family:monospace;white-space:pre-wrap;line-height:1.7;margin-bottom:12px'><b>layer 24</b> (mean P(user)=0.46)<br><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>&lt;|im_start|></span><span style='background:rgba(20,0,234,0.57)' title='P(user)=0.08'>user</span><span style='background:rgba(4,0,250,0.63)' title='P(user)=0.02'>
# </span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>see</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> the</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> below</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>
# </span><span style='background:rgba(217,0,37,0.50)' title='P(user)=0.85'>---</span><span style='background:rgba(12,0,242,0.60)' title='P(user)=0.05'>&lt;|im_end|></span><span style='background:rgba(253,0,1,0.64)' title='P(user)=0.99'>
# </span><span style='background:rgba(225,0,29,0.53)' title='P(user)=0.88'>&lt;|im_start|></span><span style='background:rgba(0,0,254,0.65)' title='P(user)=0.00'>assistant</span><span style='background:rgba(10,0,244,0.61)' title='P(user)=0.04'>
# </span><span style='background:rgba(0,0,254,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'>&lt;think></span><span style='background:rgba(1,0,253,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'>
# </span></div>

# %% [markdown]
# ## Step 3 (preliminary) — read the probe out over the seed-2004 trajectory
#
# Uses `generated_ids` from the sanity-check cell above (prompt + completion). A single forward pass over the full
# sequence reproduces the activations the model had during generation. Adjust `TAG_RE` to whatever the fake tag looks like in the transcript.

# %%
# Matches the ways a fake user tag can appear inside the assistant's own text.
TAG_RE = re.compile(r"\*\*User:?\*\*|\bUser:|<\|im_start\|>user")

# One forward pass over prompt + completion reproduces the activations seen during generation.
full_ids = generated_ids[0].tolist()
full_text = tokenizer.decode(full_ids, skip_special_tokens=False)
toks, p = readout(full_text)
display(render_html(toks, p))

# Token index of each fake tag (character offset -> first token that ends after it), searching only the completion.
enc = tokenizer(full_text, add_special_tokens=False, return_offsets_mapping=True)
tag_tok = [next(i for i, (a, b) in enumerate(enc["offset_mapping"]) if b > m.start())
           for m in TAG_RE.finditer(full_text, len(serialized_prompt))]
print("fake-tag token positions:", tag_tok)

# ---- P(user) along the trajectory -------------------------------------------------
plt.figure(figsize=(10, 3.5))
for li, L in enumerate(LAYERS):
    plt.plot(p[li], label=f"layer {L}", lw=1)
plt.axvline(prompt_length, color="k", ls="--", lw=1, label="assistant turn starts")
for t in tag_tok:
    plt.axvline(t, color="r", ls=":", lw=1)
plt.ylabel("P(user)")
plt.xlabel("token index")
plt.ylim(-0.02, 1.02)
plt.legend(loc="upper left")
plt.grid(alpha=.3)
plt.title(f"Turn-role probe along the seed-{SEED} trajectory (red dotted = fake tag)")
plt.tight_layout()
plt.savefig(OUT_DIR / "probe_score_vs_position_seed2004.png", dpi=150)
plt.show()
# Out:
# <div style='font-family:monospace;white-space:pre-wrap;line-height:1.7;margin-bottom:12px'><b>layer 8</b> (mean P(user)=0.05)<br><span style='background:rgba(255,0,0,0.65)' title='P(user)=1.00'>&lt;|im_start|></span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>user</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>
# </span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>see</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> the</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'> below</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>
# </span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>---</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>&lt;|im_end|></span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>
# </span><span style='background:rgba(210,0,44,0.48)' title='P(user)=0.83'>&lt;|im_start|></span><span style='background:rgba(27,0,227,0.54)' title='P(user)=0.11'>assistant</span><span style='background:rgba(8,0,246,0.62)' title='P(user)=0.03'>
# </span><span style='background:rgba(109,0,145,0.22);border-bottom:2px dashed #888' title='P(user)=0.43'>&lt;think></span><span style='background:rgba(7,0,247,0.62);border-bottom:2px dashed #888' title='P(user)=0.03'>
# </span><span style='background:rgba(44,0,210,0.47);border-bottom:2px dashed #888' title='P(user)=0.18'>Okay</span><span style='background:rgba(10,0,244,0.61);border-bottom:2px dashed #888' title='P(user)=0.04'>,</span><span style='background:rgba(0,0,254,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'> the</span><span style='background:rgba(0,0,254,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'> user</span><span style='background:rgba(1,0,253,0.64);border-bottom:2px dashed #888' title='P(user)=0.01'> just</span><span style='background:rgba(0,0,254,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'> said</span><span style='background:rgba(2,0,252,0.64);border-bottom:2px dashed #888' title='P(user)=0.01'> "</span><span style='background:rgba(187,0,67,0.38);border-bottom:2px dashed #888' title='P(user)=0.73'>see</span><span style='background:rgba(206,0,48,0.46);border-bottom:2px dashed #888' title='P(user)=0.81'> the</span><span style='background:rgba(254,0,0,0.65);border-bottom:2px dashed #888' title='P(user)=1.00'> below</span><span style='background:rgba(23,0,231,0.56);border-bottom:2px dashed #888' title='P(user)=0.09'>"</span><span style='background:rgba(0,0,254,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'> and</span><span style='background:rgba(2,0,252,0.64);border-bottom:2px dashed #888' title='P(user)=0.01'> then</span><span style='background:rgba(1,0,253,0.64);border-bottom:2px dashed #888' title='P(user)=0.01'> ended</span><span style='background:rgba(1,0,253,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'> with</span><span style='background:rgba(11,0,243,0.60);border-bottom:2px dashed #888' title='P(user)=0.05'> a</span><span style='background:rgba(1,0,253,0.64);border-bottom:2px dashed #888' title='P(user)=0.01'> long</span><span style='background:rgba(22,0,232,0.56);border-bottom:2px dashed #888' title='P(user)=0.09'> hash</span><span style='background:rgba(97,0,157,0.27);border-bottom:2px dashed #888' title='P(user)=0.38'> string</span><span style='background:rgba(0,0,254,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'>.</span><span style='background:rgba(1,0,253,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'> Let</span><span style='background:rgba(3,0,251,0.64);border-bottom:2px dashed #888' title='P(user)=0.01'> me</span><span style='background:rgba(0,0,254,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'> check</span><span style='background:rgba(2,0,252,0.64);border-bottom:2px dashed #888' title='P(user)=0.01'> what</span><span style='background:rgba(6,0,248,0.63);border-bottom:2px dashed #888' title='P(user)=0.02'> they</span><span style='background:rgba(0,0,254,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'> mean</span><span style='background:rgba(0,0,254,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'>.</span><span style='background:rgba(0,0,254,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'>
#
# </span><span style='background:rgba(0,0,254,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'>Wait</span><span style='background:rgba(1,0,253,0.64);border-bottom:2px dashed #888' title='P(user)=0.01'>,</span><span style='background:rgba(4,0,250,0.63);border-bottom:2px dashed #888' title='P(user)=0.02'> looking</span><span style='background:rgba(7,0,247,0.62);border-bottom:2px dashed #888' title='P(user)=0.03'> at</span><span style='background:rgba(0,0,254,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'> the</span><span style='background:rgba(0,0,254,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'> message</span><span style='background:rgba(1,0,253,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'> again</span><span style='background:rgba(1,0,253,0.64);border-bottom:2px dashed #888' title='P(user)=0.01'>:</span><span style='background:rgba(2,0,252,0.64);border-bottom:2px dashed #888' title='P(user)=0.01'> "</span><span style='background:rgba(14,0,240,0.59);border-bottom:2px dashed #888' title='P(user)=0.06'>see</span><span style='background:rgba(19,0,235,0.57);border-bottom:2px dashed #888' title='P(user)=0.08'> the</span><span style='background:rgba(28,0,226,0.54);border-bottom:2px dashed #888' title='P(user)=0.11'> below</span><span style='background:rgba(14,0,240,0.59);border-bottom:2px dashed #888' title='P(user)=0.06'> ---</span><span style='background:rgba(6,0,248,0.62);border-bottom:2px dashed #888' title='P(user)=0.03'>"</span><span style='background:rgba(1,0,253,0.64);border-bottom:2px dashed #888' title='P(user)=0.01'> followed</span><span style='background:rgba(0,0,254,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'> by</span><span style='background:rgba(0,0,254,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'> some</span><span style='background:rgba(10,0,244,0.61);border-bottom:2px dashed #888' title='P(user)=0.04'> code</span><span style='background:rgba(1,0,253,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'>.</span><span style='background:rgba(0,0,254,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'> Maybe</span><span style='background:rgba(0,0,254,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'> they</span><span style='background:rgba(0,0,254,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'> past</span><span style='background:rgba(0,0,254,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'>ed</span><span style='background:rgba(0,0,254,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'> some</span><span style='background:rgba(6,0,248,0.62);border-bottom:2px dashed #888' title='P(user)=0.03'> code</span><span style='background:rgba(0,0,254,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'> or</span><span style='background:rgba(0,0,254,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'> text</span><span style='background:rgba(3,0,251,0.64);border-bottom:2px dashed #888' title='P(user)=0.01'> they</span><span style='background:rgba(0,0,254,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'> want</span><span style='background:rgba(0,0,254,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'> me</span><span style='background:rgba(12,0,242,0.60);border-bottom:2px dashed #888' title='P(user)=0.05'> to</span><span style='background:rgba(2,0,252,0.64);border-bottom:2px dashed #888' title='P(user)=0.01'> look</span><span style='background:rgba(7,0,247,0.62);border-bottom:2px dashed #888' title='P(user)=0.03'> at</span><span style='background:rgba(0,0,254,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'>.</span><span style='background:rgba(0,0,254,0.65);border-bo
# fake-tag token positions: []

# %% [markdown]
# ## Single-prompt generate + readout
#
# Build one prompt with the exact serialization used in the sanity check, sample a completion with the same settings, and read the probe out over the whole sequence. Change `QUESTION` / `GEN_SEED` and re-run.

# %%
# Build one prompt, sample a completion with the sanity-check settings, then read the probe out
# over prompt + completion. Change QUESTION / GEN_SEED and re-run.
# Earlier settings tried: QUESTION = "---", GEN_SEED = 2038

QUESTION = "----------"
GEN_SEED = 2029
GEN_MAX_NEW_TOKENS = 384

# ---- Prompt ----------------------------------------------------------------------
messages = [{"role": "user", "content": QUESTION}]
serialized_prompt = tokenizer.apply_chat_template(
    messages,
    tokenize=False,
    add_generation_prompt=True,
    enable_thinking=cfg["enable_thinking"],
)
print("Exact serialized prompt:", repr(serialized_prompt))

# ---- Generate ------------------------------------------------------------------
inputs = tokenizer(serialized_prompt, return_tensors="pt", add_special_tokens=False).to(hf_model.device)
n_prompt = inputs["input_ids"].shape[-1]
torch.manual_seed(GEN_SEED)
torch.cuda.manual_seed_all(GEN_SEED)
with torch.inference_mode():
    gen_ids = hf_model.generate(
        **inputs, max_new_tokens=GEN_MAX_NEW_TOKENS, do_sample=True,
        temperature=cfg["temperature"], top_p=cfg["top_p"], top_k=cfg["top_k"], min_p=cfg["min_p"],
        repetition_penalty=cfg["repetition_penalty"],
        logits_processor=LogitsProcessorList([PresencePenalty(cfg["presence_penalty"], n_prompt)]),
    )[0]
completion = tokenizer.decode(gen_ids[n_prompt:], skip_special_tokens=False)
print(f"--- {len(gen_ids) - n_prompt} generated tokens ---")
print(completion)

# ---- Probe readout over the full sequence (one forward pass) ----------------------
full_text = tokenizer.decode(gen_ids, skip_special_tokens=False)
toks, p = readout(full_text)
display(render_html(toks, p))

plt.figure(figsize=(10, 3.5))
for li, L in enumerate(LAYERS):
    plt.plot(p[li], label=f"layer {L}", lw=1)
plt.axvline(n_prompt, color="k", ls="--", lw=1, label="generation starts")
plt.ylabel("P(user)")
plt.xlabel("token index")
plt.ylim(-0.02, 1.02)
plt.legend(loc="upper right")
plt.grid(alpha=.3)
plt.title(f"Turn-role probe: {QUESTION!r}, seed {GEN_SEED}")
plt.tight_layout()
plt.show()
# Out:
# Exact serialized prompt: '<|im_start|>user\n----------<|im_end|>\n<|im_start|>assistant\n<think>\n'
# --- 224 generated tokens ---
# Okay, the user just sent a message with just a separator line. Hmm, that's pretty vague. Maybe they're testing if I respond to minimal input? Or perhaps they're starting a new conversation but didn't include enough context.
#
# I need to figure out how to handle this. Since there's no specific question or topic, I should ask them to clarify. But how? A friendly prompt asking for more details might work. Let me make sure I don't assume anything. Maybe they made a mistake and hit send too soon. Or maybe it's a signal to start a topic, like "----------" as a divider.
#
# I should respond politely, indicating readiness to help but needing more information. Keep it open-ended. Something like, "Hello! How can I assist you today? Please feel free to provide more details or ask a specific question." That way, it's clear I'm here to help and prompt them for specifics. Alright, that seems appropriate.
# </think>
#
# Hello! How can I assist you today? Please feel free to provide more details or ask a specific question.<|im_end|>
# <|endoftext|>
# <div style='font-family:monospace;white-space:pre-wrap;line-height:1.7;margin-bottom:12px'><b>layer 8</b> (mean P(user)=0.05)<br><span style='background:rgba(255,0,0,0.65)' title='P(user)=1.00'>&lt;|im_start|></span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>user</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>
# </span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>----------</span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>&lt;|im_end|></span><span style='background:rgba(254,0,0,0.65)' title='P(user)=1.00'>
# </span><span style='background:rgba(237,0,17,0.58)' title='P(user)=0.93'>&lt;|im_start|></span><span style='background:rgba(50,0,204,0.45)' title='P(user)=0.20'>assistant</span><span style='background:rgba(4,0,250,0.63)' title='P(user)=0.02'>
# </span><span style='background:rgba(78,0,176,0.34);border-bottom:2px dashed #888' title='P(user)=0.31'>&lt;think></span><span style='background:rgba(5,0,249,0.63);border-bottom:2px dashed #888' title='P(user)=0.02'>
# </span><span style='background:rgba(84,0,170,0.32);border-bottom:2px dashed #888' title='P(user)=0.33'>Okay</span><span style='background:rgba(9,0,245,0.61);border-bottom:2px dashed #888' title='P(user)=0.04'>,</span><span style='background:rgba(2,0,252,0.64);border-bottom:2px dashed #888' title='P(user)=0.01'> the</span><span style='background:rgba(0,0,254,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'> user</span><span style='background:rgba(3,0,251,0.63);border-bottom:2px dashed #888' title='P(user)=0.02'> just</span><span style='background:rgba(1,0,253,0.64);border-bottom:2px dashed #888' title='P(user)=0.01'> sent</span><span style='background:rgba(2,0,252,0.64);border-bottom:2px dashed #888' title='P(user)=0.01'> a</span><span style='background:rgba(0,0,254,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'> message</span><span style='background:rgba(0,0,254,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'> with</span><span style='background:rgba(23,0,231,0.56);border-bottom:2px dashed #888' title='P(user)=0.09'> just</span><span style='background:rgba(11,0,243,0.61);border-bottom:2px dashed #888' title='P(user)=0.04'> a</span><span style='background:rgba(3,0,251,0.64);border-bottom:2px dashed #888' title='P(user)=0.01'> separator</span><span style='background:rgba(2,0,252,0.64);border-bottom:2px dashed #888' title='P(user)=0.01'> line</span><span style='background:rgba(0,0,254,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'>.</span><span style='background:rgba(76,0,178,0.35);border-bottom:2px dashed #888' title='P(user)=0.30'> Hmm</span><span style='background:rgba(5,0,249,0.63);border-bottom:2px dashed #888' title='P(user)=0.02'>,</span><span style='background:rgba(18,0,236,0.58);border-bottom:2px dashed #888' title='P(user)=0.07'> that</span><span style='background:rgba(22,0,232,0.56);border-bottom:2px dashed #888' title='P(user)=0.09'>'s</span><span style='background:rgba(4,0,250,0.63);border-bottom:2px dashed #888' title='P(user)=0.02'> pretty</span><span style='background:rgba(15,0,239,0.59);border-bottom:2px dashed #888' title='P(user)=0.06'> vague</span><span style='background:rgba(2,0,252,0.64);border-bottom:2px dashed #888' title='P(user)=0.01'>.</span><span style='background:rgba(4,0,250,0.63);border-bottom:2px dashed #888' title='P(user)=0.02'> Maybe</span><span style='background:rgba(7,0,247,0.62);border-bottom:2px dashed #888' title='P(user)=0.03'> they</span><span style='background:rgba(5,0,249,0.63);border-bottom:2px dashed #888' title='P(user)=0.02'>'re</span><span style='background:rgba(0,0,254,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'> testing</span><span style='background:rgba(8,0,246,0.62);border-bottom:2px dashed #888' title='P(user)=0.03'> if</span><span style='background:rgba(4,0,250,0.63);border-bottom:2px dashed #888' title='P(user)=0.02'> I</span><span style='background:rgba(6,0,248,0.62);border-bottom:2px dashed #888' title='P(user)=0.03'> respond</span><span style='background:rgba(23,0,231,0.56);border-bottom:2px dashed #888' title='P(user)=0.09'> to</span><span style='background:rgba(5,0,249,0.63);border-bottom:2px dashed #888' title='P(user)=0.02'> minimal</span><span style='background:rgba(8,0,246,0.62);border-bottom:2px dashed #888' title='P(user)=0.03'> input</span><span style='background:rgba(0,0,254,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'>?</span><span style='background:rgba(0,0,254,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'> Or</span><span style='background:rgba(0,0,254,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'> perhaps</span><span style='background:rgba(0,0,254,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'> they</span><span style='background:rgba(1,0,253,0.64);border-bottom:2px dashed #888' title='P(user)=0.01'>'re</span><span style='background:rgba(1,0,253,0.64);border-bottom:2px dashed #888' title='P(user)=0.01'> starting</span><span style='background:rgba(1,0,253,0.64) ...
#
# </span><span style='background:rgba(0,0,254,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'>I</span><span style='background:rgba(4,0,250,0.63);border-bottom:2px dashed #888' title='P(user)=0.02'> need</span><span style='background:rgba(1,0,253,0.64);border-bottom:2px dashed #888' title='P(user)=0.01'> to</span><span style='background:rgba(0,0,254,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'> figure</span><span style='background:rgba(2,0,252,0.64);border-bottom:2px dashed #888' title='P(user)=0.01'> out</span><span style='background:rgba(0,0,254,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'> how</span><span style='background:rgba(0,0,254,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'> to</span><span style='background:rgba(0,0,254,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'> handle</span><span style='background:rgba(0,0,254,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'> this</span><span style='background:rgba(0,0,254,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'>.</span><span style='background:rgba(0,0,254,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'> Since</span><span style='background:rgba(5,0,249,0.63);border-bottom:2px dashed #888' title='P(user)=0.02'> there</span><span style='background:rgba(6,0,248,0.62);border-bottom:2px dashed #888' title='P(user)=0.03'>'s</span><span style='background:rgba(3,0,251,0.64);border-bottom:2px dashed #888' title='P(user)=0.01'> no</span><span style='background:rgba(0,0,254,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'> specific</span><span style='background:rgba(0,0,254,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'> question</span><span style='background:rgba(0,0,254,0.65);border-bottom:2px dashed #888' title='P(user)=0.00'> or<
